# %%
import pandas as pd
import utils
import matplotlib.pyplot as plt
import os

# %%
config = utils.load_config()

# %%
log_path = config['log_path']

# %%
df_train_log = pd.read_csv(os.path.join(log_path,'20221107_train.log'),delimiter='\t')
df_batch_log = pd.read_csv(os.path.join(log_path,'20221107_train_batch.log'),delimiter='\t')
df_valid_log = pd.read_csv(os.path.join(log_path,'20221107_valid.log'),delimiter='\t')

# %%
df_train_log[['epoch','loss','acc']].head(5)
# Out:
#    epoch      loss       acc
# 0      0  0.908295  0.585736
# 1      1  0.851922  0.608498
# 2      2  0.758769  0.687405
# 3      3  0.708611  0.698027
# 4      4  0.678057  0.691958

# %%
fig,ax = plt.subplots(2,2,figsize=[10,5],constrained_layout=True)
#plt.suptitle('title')
ax[0,0].set_title('train_loss')
ax[0,0].plot(df_train_log['loss'])
ax[0,1].set_title('train_acc')
ax[0,1].plot(df_train_log['acc'])
ax[1,0].set_title('valid_loss')
ax[1,0].plot(df_valid_log['loss'])
ax[1,1].set_title('valid_acc')
ax[1,1].plot(df_valid_log['acc'])
